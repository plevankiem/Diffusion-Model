# %%
from src.diffusion_model.data.dataset import create_train_val_test_datasets
from src.diffusion_model.data.transforms import build_transform_for_split

name = "cifar10"
root = "/home/paul/Documents/Projets/Research/Diffusion-Model/src/diffusion_model/data"
download = True
image_size = None
augment_train = False
transform_by_split = {
    "train": build_transform_for_split(name, image_size),
    "test": build_transform_for_split(name, image_size),
}
datasets = create_train_val_test_datasets(name, root, transform_by_split, download, image_size)
print(datasets["train"])
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /home/paul/Documents/Projets/Research/Diffusion-Model/src/diffusion_model/data/raw
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
img, label = datasets["train"][1]

# %%
img.max()
# Out:
# tensor(0.9922)

# %%
img.min()
# Out:
# tensor(-0.9608)

# %%
img.mean()
# Out:
# tensor(0.0223)

# %%
img.shape
# Out:
# torch.Size([3, 32, 32])
